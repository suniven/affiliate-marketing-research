# %%
import pandas as pd
import re

# %%
df = pd.read_feather('./data/urls in webpage/urls-in-text-125substr-labeled.feather')
df.head()
# Out:
#                                        page  \
# 0  https://www.instagram.com/p/CaAXLI5pCLy/
# 1  https://www.instagram.com/p/CjP7cYQMrNs/
# 2  https://www.instagram.com/p/CjP7cYQMrNs/
# 3  https://www.instagram.com/p/CjP7cYQMrNs/
# 4  https://www.instagram.com/p/CjP7cYQMrNs/
#
#                                            url  is_affiliate  \
# 0                          http://lddy.no/9t58           1.0
# 1                    https://amzn.eu/d/5rJi24X           0.0
# 2         https://dl.flipkart.com/s/y_hN7wNNNN           1.0
# 3  https://blueroseone.com/store/product/nilim           0.0
# 4          https://instagram.com/the_muktarali           0.0
#
#                 query
# 0            lddy.no/
# 1                None
# 2  dl.flipkart.com/s/
# 3                None
# 4                None

# %%
# 根据 substr 提取对应的 affiliate id
def extract_id(substr, url):
    if substr == 'ad.admitad.com/goto/':
        regex = re.compile('(ad.admitad.com/goto/[0-9a-z]{30})')
        res = regex.findall(url)
        if res:
            return res[0][20:]
    elif substr == 'ad.admitad.com/g/':
        regex = re.compile('(ad.admitad.com/g/[0-9a-z]{30})')
        res = regex.findall(url)
        if res:
            return res[0][17:]
    elif substr == 'ad.zanox.com/ppc/':
        regex = re.compile('ad.zanox.com/ppc/\?([0-9]{8}C[0-9]+T)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'evyy.net/c/':
        regex = re.compile('evyy.net/c/([0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == '7eer.net/c/':
        regex = re.compile('7eer.net/c/([0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'buyeasy.by/cashback/':
        regex = re.compile('buyeasy.by/cashback/view/([0-9a-z]{32})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'buyeasy.by/redirect/':
        regex = re.compile('buyeasy.by/redirect/cpa/o/([0-9a-z]{32})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'tkqlhce.com/click-':
        regex = re.compile('tkqlhce.com/(click-[0-9]+-[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'anrdoezrs.net/click-':
        regex = re.compile('anrdoezrs.net/(click-[0-9]+-[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'dpbolvw.net/click-':
        regex = re.compile('dpbolvw.net/(click-[0-9]+-[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'jdoqocy.com/click-':
        regex = re.compile('jdoqocy.com/(click-[0-9]+-[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'kqzyfj.com/click-':
        regex = re.compile('kqzyfj.com/(click-[0-9]+-[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'designmodo.com/?u=':
        regex = re.compile('(designmodo.com/\?u=[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'online.ladbrokes.com/promoRedirect?key=':
        regex = re.compile('online.ladbrokes.com/(promoRedirect\?key=[0-9a-zA-Z]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'gopjn.com/t/':
        regex = re.compile('gopjn.com/(t/[0-9]-[0-9]+-[0-9]+-[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'pjatr.com/t/':
        regex = re.compile('pjatr.com/(t/[0-9]-[0-9]+-[0-9]+-[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'pjtra.com/t/':
        regex = re.compile('pjtra.com/(t/[0-9]-[0-9]+-[0-9]+-[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'pntra.com/t/':
        regex = re.compile('pntra.com/(t/[0-9]-[0-9]+-[0-9]+-[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'pntrac.com/t/':
        regex = re.compile('pntrac.com/(t/[0-9]-[0-9]+-[0-9]+-[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'pntrs.com/t/':
        regex = re.compile('pntrs.com/(t/[0-9]-[0-9]+-[0-9]+-[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'freshingclicks.com/?mob=':
        regex = re.compile('freshingclicks.com/(\?mob=[0-9a-zA-Z]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'bokfuj.com/cl/':
        regex = re.compile('bokfuj.com/(cl/[0-9a-z]{16})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'go2cliks.net/cpa/':
        regex = re.compile('go2cliks.net/(cpa/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.vigrxplus.com/ct/':
        regex = re.compile('www.vigrxplus.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.provestra.com/ct/':
        regex = re.compile('www.provestra.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.testosil.com/ct/':
        regex = re.compile('www.testosil.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.genf20.com/ct/':
        regex = re.compile('www.genf20.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.naturalhealthsource.com/ct/':
        regex = re.compile('www.naturalhealthsource.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.kollagenintensiv.com/ct/':
        regex = re.compile('www.kollagenintensiv.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'landing.propertysex.com/?ats=':
        regex = re.compile('landing.propertysex.com/\?ats=([0-9a-zA-Z]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'landing.trueamateurs.com/?ats=':
        regex = re.compile('landing.trueamateurs.com/\?ats=([0-9a-zA-Z]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == '511.pxf.io/':
        regex = re.compile('511.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'a.marsello.com/l/':
        regex = re.compile('a.marsello.com/l/([a-zA-Z0-9]{24})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'acmetools.pxf.io/':
        regex = re.compile('acmetools.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'adorama.rfvk.net/':
        regex = re.compile('adorama.(rfvk.net/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'advanceautoparts.rt8x.net/':
        regex = re.compile('advanceautoparts.(rt8x.net/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'AffiliateLink?partnerCode=':
        regex = re.compile('AffiliateLink\?(partnerCode=[a-zA-Z0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'affiliates.abebooks.com/':
        regex = re.compile('(affiliates.abebooks.com/[a-zA-Z0-9]{5})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'affiliates.abebooks.com/c/':
        regex = re.compile('affiliates.(abebooks.com/c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'aflink.ru/g/':
        regex = re.compile('(aflink.ru/g/[a-zA-Z0-9]{24,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'airalo.pxf.io/':
        regex = re.compile('airalo.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'allbirds.pxf.io/':
        regex = re.compile('allbirds.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'babylist.pxf.io/':
        regex = re.compile('babylist.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'carhartt.pxf.io/':
        regex = re.compile('carhartt.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'castleryus.pxf.io/':
        regex = re.compile('castleryus.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'cometeer.pxf.io/':
        regex = re.compile('cometeer.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'erinfo.pxf.io/':
        regex = re.compile('erinfo.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'madeincookware.pxf.io/':
        regex = re.compile('madeincookware.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'ninjakitchen.pxf.io/':
        regex = re.compile('ninjakitchen.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'john-lewis-and-partners.pxf.io/':
        regex = re.compile('john-lewis-and-partners.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'thefitville.pxf.io/':
        regex = re.compile('thefitville.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'truewerk.pxf.io/':
        regex = re.compile('truewerk.(pxf.io/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.vigrxmaxvolume.co/ct/':
        regex = re.compile('www.vigrxmaxvolume.co/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.Vigorelle.com/ct/':
        regex = re.compile('www.Vigorelle.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.testosil.com/ct/':
        regex = re.compile('www.testosil.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.testodren.com/ct/':
        regex = re.compile('www.testodren.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.stretchmarktherapycream.com/ct/':
        regex = re.compile('www.stretchmarktherapycream.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.skinception.com/ct/':
        regex = re.compile('www.skinception.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.semenhance.com/ct/':
        regex = re.compile('www.semenhance.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.semenax.com/ct/':
        regex = re.compile('www.semenax.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.provacyl.com/ct/':
        regex = re.compile('www.provacyl.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.prosolutionplus.com/ct/':
        regex = re.compile('www.prosolutionplus.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.prosolutionpills.com/ct/':
        regex = re.compile('www.prosolutionpills.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.profollica.com/ct/':
        regex = re.compile('www.profollica.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.proenhance.com/ct/':
        regex = re.compile('www.proenhance.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.primegenix.com/ct/':
        regex = re.compile('www.primegenix.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.illuminatural6i.com/ct/':
        regex = re.compile('www.illuminatural6i.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.hersolutiongel.com/ct/':
        regex = re.compile('www.hersolutiongel.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.erectingel.com/ct/':
        regex = re.compile('www.erectingel.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.erectin.com/ct/':
        regex = re.compile('www.erectin.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.dermeffacefx7.com/ct/':
        regex = re.compile('www.dermeffacefx7.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.cortisync.com/ct/':
        regex = re.compile('www.cortisync.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.clearpores.com/ct/':
        regex = re.compile('www.clearpores.com/(ct/[0-9]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'andie-swim.pxf.io/c/':
        regex = re.compile('andie-swim.(pxf.io/c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'berkeyfiltersaffiliateprogram.pxf.io/c/':
        regex = re.compile('berkeyfiltersaffiliateprogram.(pxf.io/c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'caddis.pxf.io/c/':
        regex = re.compile('caddis.(pxf.io/c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'mylio.pxf.io/c/':
        regex = re.compile('mylio.(pxf.io/c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'nurx.pxf.io/c/':
        regex = re.compile('nurx.(pxf.io/c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'plantpeople.pxf.io/c/':
            regex = re.compile('plantpeople.(pxf.io/c/[0-9]+/[0-9]+/[0-9]+)')
            res = regex.findall(url)
            if res:
                return res[0]
    elif substr == 'pluralsight.pxf.io/c/':
        regex = re.compile('pluralsight.(pxf.io/c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'skyscanner.pxf.io/c/':
        regex = re.compile('skyscanner.(pxf.io/c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'ali.pub/':
        regex = re.compile('(ali.pub/[0-9a-zA-Z]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'alitems.co/g/':
        regex = re.compile('alitems.co/g/([a-z0-9]{30})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'alitems.com/g/':
        regex = re.compile('alitems.com/g/([a-z0-9]{30})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'alitems.site/g/':
        regex = re.compile('alitems.site/g/([a-z0-9]{30})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'belkin.evyy.net/':
        regex = re.compile('belkin.(evyy.net/[a-zA-Z0-9]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'bitira.go2cloud.org/':
        regex = re.compile('(bitira.go2cloud.org/[a-zA-Z0-9]{4})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'caraway.go2cloud.org/':
        regex = re.compile('(caraway.go2cloud.org/[a-zA-Z0-9]{4})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'click.linksynergy.com/fs-bin/click?id=':
        regex =  re.compile('click.linksynergy.com/(fs-bin/click\?id=[a-zA-Z0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.on1.com/affiliates/idevaffiliate.php?id=':
        regex =  re.compile('www.on1.com/affiliates/(idevaffiliate.php\?id=[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'www.nitrado-aff.com/':
        regex =  re.compile('www.(nitrado-aff.com/[0-9A-Z]+/[0-9A-Z]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'urbanedcsupply.com/?rfsn=':
        regex =  re.compile('urbanedcsupply.com/(\?rfsn=[0-9a-z\.]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'trezor.go2cloud.org/':
        regex =  re.compile('(trezor.go2cloud.org/[a-zA-Z0-9]{4})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'traeger.uym8.net/c/':
        regex =  re.compile('traeger.uym8.net/(c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'traeger.uym8.net/':
        regex =  re.compile('traeger.(uym8.net/[0-9a-zA-Z]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'the-realreal.2pxhba.net/c/':
        regex =  re.compile('the-realreal.2pxhba.net/(c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'soundcore.sjv.io/':
        regex =  re.compile('soundcore.(sjv.io/[0-9a-zA-Z]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'govee.sjv.io/':
        regex =  re.compile('govee.(sjv.io/[0-9a-zA-Z]{13})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'noggin.sjv.io/':
        regex =  re.compile('noggin.(sjv.io/[0-9a-zA-Z]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'nordvpn.sjv.io/':
        regex =  re.compile('nordvpn.(sjv.io/[0-9a-zA-Z]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'omio.sjv.io/':
        regex =  re.compile('omio.(sjv.io/[0-9a-zA-Z]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'partner.canva.com/c/':
        regex =  re.compile('partner.canva.com/(c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'mucoff.sjv.io/c/':
        regex =  re.compile('mucoff.sjv.io/(c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'macpaw.audw.net/c/':
        regex =  re.compile('macpaw.audw.net/(c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'powerdot.4byfvk.net/c/':
        regex =  re.compile('powerdot.4byfvk.net/(c/[0-9]+/[0-9]+/[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'rstyle.me/+':
        regex =  re.compile('rstyle.me/(\+[0-9a-zA-Z]{22})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'rstyle.me/n/':
        regex =  re.compile('rstyle.me/(n/[0-9a-zA-Z]{10})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'dl.flipkart.com/s/':
        regex =  re.compile('dl.flipkart.com/(s/[0-9a-zA-Z]{10})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'epidemicsound.com/referral/':
        regex =  re.compile('epidemicsound.com/(referral/[0-9a-zA-Z]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'epnclick.ru/cashback/view/':
        regex =  re.compile('epnclick.ru/(cashback/view/[0-9a-zA-Z]{32})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'epnclick.ru/redirect/cpa/':
        regex =  re.compile('epnclick.ru/redirect/(cpa/u/[0-9a-zA-Z]{32})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'epnclick.ru/redirect/cpa/o/':
        regex =  re.compile('epnclick.ru/redirect/(cpa/o/[0-9a-zA-Z]{32})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'shoprongrong.com/?aff=':
        regex =  re.compile('(shoprongrong.com/\?aff=[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'shopstyle.it/l/':
        regex =  re.compile('(shopstyle.it/l/[0-9a-zA-Z]{5})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'shp.ee/':
        regex =  re.compile('(shp.ee/[0-9a-zA-Z]{7})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'shrsl.com/':
        regex =  re.compile('(shrsl.com/[0-9a-zA-Z]{7})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'epngo.bz/cashback_index/':
        regex =  re.compile('epngo.bz/(cashback_index/[0-9a-zA-Z]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'epngo.bz/cashback_install_plugin/':
        regex =  re.compile('epngo.bz/(cashback_install_plugin/[0-9a-zA-Z]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'epngo.bz/cashback_joinusnow/':
        regex =  re.compile('epngo.bz/(cashback_joinusnow/[0-9a-zA-Z]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'fbuy.me/':
        regex =  re.compile('(fbuy.me/[0-9a-zA-Z]{5})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'freshingclicks.com/?mob=':
        regex =  re.compile('(freshingclicks.com/\?mob=[0-9a-zA-Z]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'fxo.co/':
        regex =  re.compile('(fxo.co/[0-9a-zA-Z]{3,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'go.nordvpn.net/':
        regex =  re.compile('(go.nordvpn.net/[0-9a-zA-Z]{5})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'gotbest.by/cashback/':
        regex =  re.compile('gotbest.by/(cashback/view/[0-9a-zA-Z]{32})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'gymboree.fhsxpf.net/':
        regex =  re.compile('gymboree.(fhsxpf.net/[0-9a-zA-Z]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'homyanus.com/g/':
        regex =  re.compile('homyanus.com/(g/[0-9a-zA-Z]{30})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'idevaffiliate.php?id=':
        regex =  re.compile('(idevaffiliate.php\?id=[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'inkthemes.com/members/aff/go/':
        regex =  re.compile('inkthemes.com/members/(aff/go/[a-zA-Z0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'j.moomoo.com/':
        regex =  re.compile('(j.moomoo.com/[0-9a-zA-Z]{6})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'katuhus.com/g/':
        regex =  re.compile('katuhus.com/(g/[0-9a-zA-Z]{30})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'lddy.no/':
        regex =  re.compile('(lddy.no/[0-9a-zA-Z]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'lddy.no/':
        regex =  re.compile('(lddy.no/[0-9a-zA-Z]{4,})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'partner.discovery-japan.me/products/?affID=':
        regex =  re.compile('partner.(discovery-japan.me/products/\?affID=[0-9]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 's.click.aliexpress.com/e/':
        regex =  re.compile('s.click.(aliexpress.com/e/[_a-zA-Z0-9]{7,8})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'share.epidemicsound.com/':
        regex =  re.compile('(share.epidemicsound.com/[0-9a-zA-Z]{5})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'share.honeybook.com/':
        regex =  re.compile('(share.honeybook.com/[0-9a-zA-Z]+)')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'shareasale.com/r.cfm?b=':
        regex =  re.compile('shareasale.com/r.cfm\?b=[0-9]')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'shopeasy.by/cashback/':
        regex =  re.compile('shopeasy.by/(cashback/view/[0-9a-zA-Z]{32})')
        res = regex.findall(url)
        if res:
            return res[0]
    elif substr == 'shopeasy.by/redirect/cpa/o/':
        regex =  re.compile('shopeasy.by/redirect/(cpa/o/[0-9a-zA-Z]{32})')
        res = regex.findall(url)
        if res:
            return res[0]

    return None

# %%
df.shape
# Out:
# (158067, 4)

# %%
df[df['is_affiliate']==1]
# Out:
#                                                      page  \
# 0                https://www.instagram.com/p/CaAXLI5pCLy/
# 2                https://www.instagram.com/p/CjP7cYQMrNs/
# 7                https://m.facebook.com/2332838300302097/
# 8       https://scanfrost.bezaiservices.com/scanfrost-...
# 9       https://www.tiktok.com/@livcece11/video/713843...
# ...                                                   ...
# 158058  https://www.tiktok.com/music/original-sound-Ho...
# 158059  https://www.pinterest.com/pin/598064025497632853/
# 158061  https://www.pinterest.com/pin/598064025497632853/
# 158063  https://www.pinterest.com/pin/598064025497632853/
# 158065  https://www.pinterest.com/pin/598064025497632853/
#
#                                                       url  is_affiliate  \
# 0                                     http://lddy.no/9t58           1.0
# 2                    https://dl.flipkart.com/s/y_hN7wNNNN           1.0
# ...

# %%
df[df['is_affiliate']==0]
# Out:
#                                                      page  \
# 1                https://www.instagram.com/p/CjP7cYQMrNs/
# 3                https://www.instagram.com/p/CjP7cYQMrNs/
# 4                https://www.instagram.com/p/CjP7cYQMrNs/
# 5                https://www.instagram.com/p/CjP7cYQMrNs/
# 6                https://www.instagram.com/p/CjP7cYQMrNs/
# ...                                                   ...
# 158056  https://www.rootsandrivershomestead.com/post/s...
# 158060  https://www.pinterest.com/pin/598064025497632853/
# 158062  https://www.pinterest.com/pin/598064025497632853/
# 158064  https://www.pinterest.com/pin/598064025497632853/
# 158066  https://www.pinterest.com/pin/598064025497632853/
#
#                                                 url  is_affiliate query  \
# 1                         https://amzn.eu/d/5rJi24X           0.0  None
# 3       https://blueroseone.com/store/product/nilim           0.0  None
# ...

# %%
from tqdm import tqdm

for i in tqdm(range(len(df))):
    if df.at[i, 'is_affiliate'] == 1:
        id = extract_id(df.at[i, 'query'], df.at[i, 'url'])
        if id:
            df.at[i, 'affiliate_id'] = id
# Out:
# ...
# 100%|██████████| 158067/158067 [00:01<00:00, 129521.32it/s]

# %%
df.head()
# Out:
#                                        page  \
# 0  https://www.instagram.com/p/CaAXLI5pCLy/
# 1  https://www.instagram.com/p/CjP7cYQMrNs/
# 2  https://www.instagram.com/p/CjP7cYQMrNs/
# 3  https://www.instagram.com/p/CjP7cYQMrNs/
# 4  https://www.instagram.com/p/CjP7cYQMrNs/
#
#                                            url  is_affiliate  \
# 0                          http://lddy.no/9t58           1.0
# 1                    https://amzn.eu/d/5rJi24X           0.0
# 2         https://dl.flipkart.com/s/y_hN7wNNNN           1.0
# 3  https://blueroseone.com/store/product/nilim           0.0
# 4          https://instagram.com/the_muktarali           0.0
#
#                 query  affiliate_id
# 0            lddy.no/  lddy.no/9t58
# 1                None           NaN
# 2  dl.flipkart.com/s/           NaN
# 3                None           NaN
# 4                None           NaN

# %%
ids = df[~df['affiliate_id'].isna()].affiliate_id.to_list()

# %%
len(ids)
# Out:
# 25556

# %%
ids = list(set(ids))

# %%
len(ids)
# Out:
# 9520

# %%
df1 = pd.DataFrame(data=ids, columns=['affiliate_id'])
df1
# Out:
#                    affiliate_id
# 0                  s/Jb6y05uuuN
# 1          shopstyle.it/l/bbDvt
# 2       +v8Cs4ByzzE6k4r53uyFCiA
# 3     aliexpress.com/e/_DczxIed
# 4      5d34598f0880c036f8c6cd31
# ...                         ...
# 9515               n/daxbq9b5nq
# 9516  aliexpress.com/e/_DDVVvhL
# 9517       lddy.no/1cey4Digital
# 9518             ali.pub/o1edhF
# 9519             shp.ee/myvrney
#
# [9520 rows x 1 columns]

# %%
df1.to_csv('./data/affiliate id/affiliate-id-125substr.csv', index=False)
