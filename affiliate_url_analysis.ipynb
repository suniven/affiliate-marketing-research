# %%
import pandas as pd

# %%
df = pd.read_feather('./data/urls in webpage/urls-in-text-125substr-labeled.feather')

# %%
df.shape
# Out:
# (525982, 4)

# %%
df.head()
# Out:
#                                        page  \
# 0  https://m.facebook.com/3689818277773221/
# 1  https://m.facebook.com/3689818277773221/
# 2   https://m.facebook.com/664460377570528/
# 3   https://m.facebook.com/664460377570528/
# 4   https://m.facebook.com/754507955416474/
#
#                                                  url  is_affiliate  \
# 0  https://ad.admitad.com/g/jxzxvuqvaqd3285f148b8...             1
# 1  https://ad.admitad.com/g/jxzxvuqvaqd3285f148b8...             1
# 2  https://ad.admitad.com/g/34hqy5z6am89417a158d3...             1
# 3  https://ad.admitad.com/g/34hqy5z6am89417a158d3...             1
# 4  https://ad.admitad.com/g/e94d4c65e048b83900213...             1
#
#                query
# 0  ad.admitad.com/g/
# 1  ad.admitad.com/g/
# 2  ad.admitad.com/g/
# 3  ad.admitad.com/g/
# 4  ad.admitad.com/g/

# %%
df[df['is_affiliate']==1]
# Out:
#                                                      page  \
# 0                https://m.facebook.com/3689818277773221/
# 1                https://m.facebook.com/3689818277773221/
# 2                 https://m.facebook.com/664460377570528/
# 3                 https://m.facebook.com/664460377570528/
# 4                 https://m.facebook.com/754507955416474/
# ...                                                   ...
# 525977  https://m.facebook.com/BeebesBargainsOnABudget...
# 525978  https://m.facebook.com/BeebesBargainsOnABudget...
# 525979           https://m.facebook.com/1097438213955334/
# 525980           https://m.facebook.com/1097438213955334/
# 525981            https://m.facebook.com/131679195266076/
#
#                                                       url  is_affiliate  \
# 0       https://ad.admitad.com/g/jxzxvuqvaqd3285f148b8...             1
# 1       https://ad.admitad.com/g/jxzxvuqvaqd3285f148b8...             1
# ...

# %%
df_aff = pd.read_csv('./data/urls in webpage/affiliate-urls-with-redirection-125substr.csv')

# %%
df_aff.shape
# Out:
# (16127, 6)

# %%
df_aff[~df_aff['final_page'].isna()]
# Out:
#                                                      url  \
# 0          https://rstyle.me/+AgJy1vHgb3IpgHads8xVoQBlue
# 1      https://alitems.co/g/uq1eoj16ck24f51d248db6d17...
# 2      https://www.epidemicsound.com/referral/b2zv......
# 4                           http://rstyle.me/n/968td9sx6
# 5         https://www.epidemicsound.com/referral/b6u5p1/
# ...                                                  ...
# 16121          http://epngo.bz/cashback_joinusnow/baikz5
# 16122                            https://shrsl.com/zyrm-
# 16123                         http://shopstyle.it/l/piOE
# 16124          https://rstyle.me/+HNPckVclgR2ZOQalNIngFw
# 16125                    https://adorama.rfvk.net/x9dREx
#
#                                               redirect_1  \
# 0      https://www.shopltk.com/?redirect_type=code_11...
# 1      https://promotion.aliexpress.ru/wow/gcp/aer/da...
# 2      https://www.epidemicsound.com/referral/b2zv......
# ...

# %%
df_aff.at[13573, 'url']
# Out:
# 'https://rstyle.me/n/c9bn7gb5nqf'
