# %%
import pandas as pd

# %%
df = pd.read_csv('./data_all/urls-with-redirection-labeled.csv')

# %%
df
# Out:
#                                          original_url  \
# 0                             https://alii.pub/6o3dam
# 1       https://www.pinterest.com/singlemommywinning/
# 2                       http://rstyle.me/n/b9i9d29vde
# 3           https://rstyle.me/+IMNF676MkVHNh9aOf9TaEQ
# 4                     https://bit.ly/valencia_tuscany
# ...                                               ...
# 753233                        https://t.co/YJRLLtBAuR
# 753234                        https://t.co/9ogADdxF7O
# 753235                        https://t.co/Sum8Z2CGl6
# 753236                        https://t.co/5cd28dNtPK
# 753237                        https://t.co/Dx0HRAVVF2
#
#                                             redirect_urls  \
# 0       ['https://alii.pub/6o3dam'\n 'https://allshops...
# 1                                                     NaN
# 2                       ['http://rstyle.me/n/b9i9d29vde']
# 3                                                     NaN
# ...

# %%
df[df['source'].str.contains('Twitter') & (df['is_affiliate'] == 1)]
# Out:
#                    original_url  \
# 684319  https://t.co/uAvLfc3OTb
# 684323  https://t.co/uAvLfc4mIJ
# 684339  https://t.co/ffq0BeBm5x
# 684348  https://t.co/rj8A2RksE4
# 684352  https://t.co/rRNMpSicfl
# ...                         ...
# 753230  https://t.co/GkEDvPr74X
# 753232  https://t.co/Yn0XMsPO4o
# 753233  https://t.co/YJRLLtBAuR
# 753234  https://t.co/9ogADdxF7O
# 753235  https://t.co/Sum8Z2CGl6
#
#                                             redirect_urls  \
# 684319  ['https://t.co/uAvLfc3OTb', 'https://www.clear...
# 684323  ['https://t.co/uAvLfc4mIJ', 'https://www.clear...
# 684339  ['https://t.co/ffq0BeBm5x', 'https://www.clear...
# 684348  ['https://t.co/rj8A2RksE4', 'https://www.clear...
# 684352  ['https://t.co/rRNMpSicfl', 'https://www.clear...
# ...                                                   ...
# 753230  ['https://t.co/GkEDvPr74X', 'https://shp.ee/9q...
# 753232  ['https://t.co/Yn0XMsPO4o', 'https://shopee.co...
# ...

# %%
df[df['source'].str.contains('YouTube') & (df['is_affiliate'] == 1)]
# Out:
#                                              original_url  \
# 0                                 https://alii.pub/6o3dam
# 2                           http://rstyle.me/n/b9i9d29vde
# 3               https://rstyle.me/+IMNF676MkVHNh9aOf9TaEQ
# 6                            https://go.magik.ly/ml/e66t/
# 8                         https://NordVPN.com/madewithlau
# ...                                                   ...
# 136099  http://aflink.ru/g/w2thevpdzs209f4a6307c410d1f...
# 136104          https://rstyle.me/+8Hp1zbcEIKWyMH5ABqXVzg
# 136105                            https://shrsl.com/2yu4r
# 136107                    https://rstyle.me/n/dak4jfb5nqf
# 136108                              http://ali.pub/2gixmm
#
#                                             redirect_urls  \
# 0       ['https://alii.pub/6o3dam'\n 'https://allshops...
# 2                       ['http://rstyle.me/n/b9i9d29vde']
# 3                                                     NaN
# ...

# %%
df[df['source'].str.contains('Google') & (df['is_affiliate'] == 1)]
# Out:
#                                      original_url  \
# 136116      https://uphold.sjv.io/c/3061345/10842
# 136126          https://bestbuy.7tiv.net/Wqqnr3My
# 136127     https://share.epidemicsound.com/qxim5a
# 136132  https://rstyle.me/+gnU_tqU_K3kOd9DYl-uawA
# 136142                      http://ali.pub/3hxgt1
# ...                                           ...
# 684209  https://rstyle.me/+h-RjYzwm6rL57Qna9r_Zrg
# 684214                      http://ali.pub/5cmtas
# 684220                 http://shopstyle.it/l/SkWM
# 684239                       http://fbuy.me/tA62v
# 684249                   http://ow.ly/mh0K30exvq0
#
#                                             redirect_urls  \
# 136116                                                NaN
# 136126                                                NaN
# 136127         ['https://share.epidemicsound.com/qxim5a']
# 136132                                                NaN
# 136142  ['http://ali.pub/3hxgt1' 'https://ali.pub/3hxg...
# ...
