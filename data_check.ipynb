# %%
import pandas as pd

# %%
df = pd.read_csv('./data_all/urls-with-redirection.csv')

# %%
df
# Out:
#                                          original_url  \
# 0                             https://alii.pub/6o3dam
# 1       https://www.pinterest.com/singlemommywinning/
# 2                       http://rstyle.me/n/b9i9d29vde
# 3           https://rstyle.me/+IMNF676MkVHNh9aOf9TaEQ
# 4                     https://bit.ly/valencia_tuscany
# ...                                               ...
# 753233                        https://t.co/YJRLLtBAuR
# 753234                        https://t.co/9ogADdxF7O
# 753235                        https://t.co/Sum8Z2CGl6
# 753236                        https://t.co/5cd28dNtPK
# 753237                        https://t.co/Dx0HRAVVF2
#
#                                             redirect_urls  \
# 0       ['https://alii.pub/6o3dam'\n 'https://allshops...
# 1                                                     NaN
# 2                       ['http://rstyle.me/n/b9i9d29vde']
# 3                                                     NaN
# ...
